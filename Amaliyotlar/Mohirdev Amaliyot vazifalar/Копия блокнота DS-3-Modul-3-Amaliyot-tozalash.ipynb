# %% [markdown]
# # ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # **DATA SCIENCE VA SUN'IY INTELLEKT PRAKTIKUM**
#
# ## 3.2 Ma'lumotlarni tayyorlash
#
# # **AMALIYOT**
# ## Ma'lumotlarga ishlov berish

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mukhammad-irmatov/health_dataset/main/healt_info.csv")
df.head(3)
# Out:
#    Sno  AGE     SEX CASTE_NAME CATEGORY_CODE CATEGORY_NAME SURGERY_CODE  \
# 0    1   56  Female         BC            M6    NEPHROLOGY         M6.5
# 1    2   37    Male         BC            M6    NEPHROLOGY         M6.5
# 2    3   50    Male         BC            M6    NEPHROLOGY         M6.5
#
#                             SURGERY      VILLAGE MANDAL_NAME  ...  \
# 0  Maintenance Hemodialysis For Crf       Lolugu     Ponduru  ...
# 1  Maintenance Hemodialysis For Crf    Borivanka      Kaviti  ...
# 2  Maintenance Hemodialysis For Crf  Kapasakuddi      Kaviti  ...
#
#          CLAIM_DATE CLAIM_AMOUNT                                HOSP_NAME  \
# 0  22-03-2017 20:25        11000  Rims Govt. General Hospital, Srikakulam
# 1  22-03-2017 20:25        11000  Rims Govt. General Hospital, Srikakulam
# 2  22-03-2017 20:25        11500  Rims Govt. General Hospital, Srikakulam
#
#   HOSP_TYPE  HOSP_DISTRICT      SURGERY_DATE    DISCHARGE_DATE  \
# 0         G     Srikakulam  06-08-2013 00:00  07-09-2013 00:00
# 1         G     Srikakulam  08-08-2013 00:00  09-09-2013 00:00
# 2         G     Srikakulam  15-08-2013 00:00  18-10-2013 00:00
#
#   Mortality Y / N MORTALITY_DATE SRC_REGISTRATION
# 0              NO            NaN                D
# 1              NO            NaN                D
# 2              NO            NaN                D
#
# [3 rows x 23 columns]

# %% [markdown]
# Bu dataset sug'urta kompaniyasining real ma'lumotlardan tuzilgan. Bu datasetda 480000 qator sug'urta ma'lumotlar tashkil topgan.
# Quyida datasetning ba'zi ustunlari haqida qisqacha ma'lumot
#
# *   Sno = seriya raqami
# *   AGE = yoshi
# *   SEX = jinsi (female = ayol, male = erkak)
# *   CASTE_NAME = kasta nomi (Hindistonda har bir inson ma'lum bir kastaga oid bo'ladi)
# *   CATEGORY_CODE = kategoriya kodi
# *   CATEGORY_Name = kategoriya nomi
# *   SURGERY_CODE = operatsiya kodi
# *   Mandal_Name = mandal nomlanishi ya'ni familiyasi desak ham bo'ladi
# *   Mortality Y/N = vafot etgan yoki vafot etmaganligi
# *   MORTALITY_DATE = qachon vafot etganligi

# %% [markdown]
# ### **1-mashq**. Datasetdagi barcha takrorlangan qatorlar sonini toping

# %%
# Javobni shuyerga yozing
df.duplicated().sum()
# Out:
# 0

# %%
#@title **To'g'ri javob**
sum(df.duplicated())
# Out:
# 0

# %% [markdown]
# #### **2-mashq**. Datasetdagi quyidagi ustunlar o'chirib yuborilsin:<br>
# *   Sno
# *   CATEGORY_CODE
# *   SURGERY_CODE
# *   MANDAL_NAME
# *   DISTRICT_NAME
# *   HOSP_DISTRICT
# <BR>

# %%
# Javobni shuyerga yozing
df.drop(['CATEGORY_CODE','SURGERY_CODE','MANDAL_NAME','DISTRICT_NAME','HOSP_DISTRICT'],axis="columns",inplace=True)
df
# Out:
#            Sno  AGE     SEX CASTE_NAME             CATEGORY_NAME  \
# 0            1   56  Female         BC                NEPHROLOGY
# 1            2   37    Male         BC                NEPHROLOGY
# 2            3   50    Male         BC                NEPHROLOGY
# 3            4   45    Male         BC                NEPHROLOGY
# 4            5   54    Male         BC                NEPHROLOGY
# ...        ...  ...     ...        ...                       ...
# 335389  335390   65    Male         SC    OPHTHALMOLOGY  SURGERY
# 335390  335391   54  Female         OC          MEDICAL ONCOLOGY
# 335391  335392   19  Female         SC          MEDICAL ONCOLOGY
# 335392  335393   50    Male         BC  GENITO URINARY SURGERIES
# 335393  335394   46  Female         SC          MEDICAL ONCOLOGY
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE      PREAUTH_DATE  PREAUTH_AMT  \
# 0                        Lolugu  03-08-2013 20:38        12500
# 1                     Borivanka  06-08-2013 07:26        12500
# 2                   Kapasakuddi  09-08-2013 18:30        12500
# 3                   Telikipenta  24-08-2013 19:37        12500
# 4                 Thandemvalasa  28-08-2013 17:03        12500
# ...                         ...               ...          ...
# 335389             Chintalapudi  08-06-2017 06:40        23320
# 335390  Udayagiri @ Kondayapale  05-06-2017 22:35         7140
# 335391                  Vinduru  06-06-2017 06:13         5000
# 335392                Duppituru  05-06-2017 23:37        25000
# 335393             Ananthavaram  06-06-2017 23:02         2040
#
#               CLAIM_DATE  CLAIM_AMOUNT  \
# 0       22-03-2017 20:25         11000
# 1       22-03-2017 20:25         11000
# 2       22-03-2017 20:25         11500
# 3       22-03-2017 20:25         11000
# 4       22-03-2017 20:25         11000
# ...                  ...           ...
# 335389  04-08-2017 21:23         23320
# 335390  02-08-2017 19:11          7140
# 335391  04-10-2017 19:46          5000
# 335392  04-08-2017 20:59         25000
# 335393  09-08-2017 19:43          2040
#
#                                                 HOSP_NAME HOSP_TYPE  \
# 0                 Rims Govt. General Hospital, Srikakulam         G
# 1                 Rims Govt. General Hospital, Srikakulam         G
# 2                 Rims Govt. General Hospital, Srikakulam         G
# 3                 Rims Govt. General Hospital, Srikakulam         G
# 4                 Rims Govt. General Hospital, Srikakulam         G
# ...                                                   ...       ...
# 335389                                Sankar Eye Hospital         C
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...         C
# 335391                                    M.N.J.Hospitals         G
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL         C
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...         C
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0       06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1       08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2       15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3       24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4       31-08-2013 00:00  02-10-2013 00:00              NO            NaN
# ...                  ...               ...             ...            ...
# 335389  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335390  06-06-2017 00:00  06-06-2017 00:00              NO            NaN
# 335391  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335392  06-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335393  07-06-2017 00:00  07-06-2017 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 0                     D
# 1                     D
# 2                     D
# 3                     D
# 4                     D
# ...                 ...
# 335389                D
# 335390                D
# 335391                D
# 335392                D
# 335393               MC
#
# [335394 rows x 18 columns]

# %%
#@title **To'g'ri javob**
df.drop(['Sno','CATEGORY_CODE','SURGERY_CODE','MANDAL_NAME','DISTRICT_NAME','HOSP_DISTRICT'],axis='columns',inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-130bcd797ecf> in <cell line: 0>()
#       1 #@title **To'g'ri javob**
# ----> 2 df.drop(['Sno','CATEGORY_CODE','SURGERY_CODE','MANDAL_NAME','DISTRICT_NAME','HOSP_DISTRICT'],axis='columns',inplace=True)
#       3 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['CATEGORY_CODE', 'SURGERY_CODE', 'MANDAL_NAME', 'DISTRICT_NAME', 'HOSP_DISTRICT'] not found in axis"

# %% [markdown]
# #### **3-mashq**. Datasetdagi sex(jinsi) nomli qatordagi qiymatlarni unique funksiyasi orqali tekshiring.

# %%
# Javobni shuyerga yozing
df.SEX.unique()
# Out:
# array(['Female', 'Male', 'Male(Child)', 'Female(Child)', 'FEMALE'],
#       dtype=object)

# %%
#@title **To'g'ri javob**
df["SEX"].unique()

# %% [markdown]
# #### **4-mashq**. Datasetdagi sex(jinsi) nomli qatordagi qiymatlarni **Erkak** va **Ayol** ga o'zgartiring:
# O'zgartirish quyidagicha bo'lsin:
#
#
# *   Male -> Erkak
# *   Male(child) -> Erkak
# *   Female - > Ayol
# *   Female(child) - Ayol
# *   MALE -> Erkak
# *   FEMALE -> Ayol

# %%
# Javobni shuyerga yozing
arr={'Male': 'Erkak','Male(child)':'Erkak','Female':'Ayol','Female(child)':'Ayol','MALE':'Erkak','FEMALE':'Ayol'}
df.SEX.replace(arr,inplace=True)
# Out:
# <ipython-input-34-fc3ced5a3871>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.SEX.replace(arr,inplace=True)

# %%
df
# Out:
#            Sno  AGE    SEX CASTE_NAME             CATEGORY_NAME  \
# 0            1   56   Ayol         BC                NEPHROLOGY
# 1            2   37  Erkak         BC                NEPHROLOGY
# 2            3   50  Erkak         BC                NEPHROLOGY
# 3            4   45  Erkak         BC                NEPHROLOGY
# 4            5   54  Erkak         BC                NEPHROLOGY
# ...        ...  ...    ...        ...                       ...
# 335389  335390   65  Erkak         SC    OPHTHALMOLOGY  SURGERY
# 335390  335391   54   Ayol         OC          MEDICAL ONCOLOGY
# 335391  335392   19   Ayol         SC          MEDICAL ONCOLOGY
# 335392  335393   50  Erkak         BC  GENITO URINARY SURGERIES
# 335393  335394   46   Ayol         SC          MEDICAL ONCOLOGY
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE      PREAUTH_DATE  PREAUTH_AMT  \
# 0                        Lolugu  03-08-2013 20:38        12500
# 1                     Borivanka  06-08-2013 07:26        12500
# 2                   Kapasakuddi  09-08-2013 18:30        12500
# 3                   Telikipenta  24-08-2013 19:37        12500
# 4                 Thandemvalasa  28-08-2013 17:03        12500
# ...                         ...               ...          ...
# 335389             Chintalapudi  08-06-2017 06:40        23320
# 335390  Udayagiri @ Kondayapale  05-06-2017 22:35         7140
# 335391                  Vinduru  06-06-2017 06:13         5000
# 335392                Duppituru  05-06-2017 23:37        25000
# 335393             Ananthavaram  06-06-2017 23:02         2040
#
#               CLAIM_DATE  CLAIM_AMOUNT  \
# 0       22-03-2017 20:25         11000
# 1       22-03-2017 20:25         11000
# 2       22-03-2017 20:25         11500
# 3       22-03-2017 20:25         11000
# 4       22-03-2017 20:25         11000
# ...                  ...           ...
# 335389  04-08-2017 21:23         23320
# 335390  02-08-2017 19:11          7140
# 335391  04-10-2017 19:46          5000
# 335392  04-08-2017 20:59         25000
# 335393  09-08-2017 19:43          2040
#
#                                                 HOSP_NAME HOSP_TYPE  \
# 0                 Rims Govt. General Hospital, Srikakulam         G
# 1                 Rims Govt. General Hospital, Srikakulam         G
# 2                 Rims Govt. General Hospital, Srikakulam         G
# 3                 Rims Govt. General Hospital, Srikakulam         G
# 4                 Rims Govt. General Hospital, Srikakulam         G
# ...                                                   ...       ...
# 335389                                Sankar Eye Hospital         C
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...         C
# 335391                                    M.N.J.Hospitals         G
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL         C
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...         C
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0       06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1       08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2       15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3       24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4       31-08-2013 00:00  02-10-2013 00:00              NO            NaN
# ...                  ...               ...             ...            ...
# 335389  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335390  06-06-2017 00:00  06-06-2017 00:00              NO            NaN
# 335391  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335392  06-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335393  07-06-2017 00:00  07-06-2017 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 0                     D
# 1                     D
# 2                     D
# 3                     D
# 4                     D
# ...                 ...
# 335389                D
# 335390                D
# 335391                D
# 335392                D
# 335393               MC
#
# [335394 rows x 18 columns]

# %%
#@title **To'g'ri javob**
dict = {"Male":"Erkak","Male(child)":"Erkak", "Female":"Ayol","Female(child)":"Ayol","MALE":"Erkak","FEMALE":"Ayol"}
df["SEX"] = df["SEX"].map(dict)

# %% [markdown]
# #### **5-mashq**. Endi xuddi shu SEX columndagi ma'lumotlarni raqamlarga o'zgartiring: Erkaklarni 1 raqamiga, Ayollarni 0 raqamiga o'zgartiring.
# *   Erkak -> 1
# *   Ayol -> 0

# %%
# Javobni shuyerga yozing
arr1={'Erkak':1,'Ayol':0}
df['SEX']=df['SEX'].map(arr1)
df.sample(5)
# Out:
#            Sno  AGE  SEX  CASTE_NAME                       CATEGORY_NAME  \
# 269123  269124   60  1.0  Minorities  CARDIAC AND CARDIOTHORACIC SURGERY
# 108128  108129   68  0.0          BC                          NEPHROLOGY
# 42426    42427    0  NaN          SC                          PEDIATRICS
# 50698    50699   20  0.0          BC  CARDIAC AND CARDIOTHORACIC SURGERY
# 55256    55257   30  1.0          ST  ORTHOPEDIC  SURGERY AND PROCEDURES
#
#                                                   SURGERY        VILLAGE  \
# 269123  Coronary Balloon Angioplasty with Drug eluting...     Edupugallu
# 108128                   Maintenance Hemodialysis For Crf  Singannagudem
# 42426   Medicalmanagement of Preterm baby of 33 To 34 ...        Koppolu
# 50698   Ross procedure - Intracardiac repair of comple...   Bhimalapuram
# 55256                Bone Grafting As Exclusive Procedure  Bandi Atmakur
#
#             PREAUTH_DATE  PREAUTH_AMT        CLAIM_DATE  CLAIM_AMOUNT  \
# 269123  12-04-2017 00:03        66310  07-07-2017 19:13         61310
# 108128  22-11-2016 09:58        12500  10-01-2017 23:20         12500
# 42426   03-09-2016 16:58        35000  10-01-2017 01:09         35000
# 50698   19-09-2016 22:35       111700  18-01-2017 16:17        111700
# 55256   24-09-2016 10:19        20000  10-01-2017 21:57          9100
#
#                                           HOSP_NAME HOSP_TYPE  \
# 269123            SENTINI HOSPITALS PRIVATE LIMITED         C
# 108128                            KAMINENI HOSPITAL         C
# 42426                    Venkataramana Nursing Home         C
# 50698                      SUNSHINE HEART INSTITUTE         C
# 55256   Shantiram Medical College  General Hospital         C
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 269123  15-04-2017 00:00  18-04-2017 00:00              NO            NaN
# 108128  22-11-2016 00:00  13-12-2016 00:00              NO            NaN
# 42426   02-09-2016 00:00  07-09-2016 00:00              NO            NaN
# 50698   23-09-2016 00:00  28-09-2016 00:00              NO            NaN
# 55256   01-10-2016 00:00  14-10-2016 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 269123                D
# 108128                D
# 42426                 D
# 50698                 D
# 55256                 D

# %%
#@title **To'g'ri javob**
dict2 = {'Erkak':1, 'Ayol':0}
df["SEX"] = df["SEX"].map(dict2)
df.head(5)

# %% [markdown]
# #### **6-mashq**. Shu jarayonni HOSP_TYPE ustuni uchun ham amalga oshiring.
# *   G - General hospital (umumiy kasalxona) degani
# *   C - Special hospital (maxsus kasalxona) degani
# <br><b>O'zgarish quyidagicha bo'lsin:</b>
# *   G -> Umumiy
# *   C -> Maxsus

# %%
# Javobni shuyerga yozing
df['HOSP_TYPE']=df.HOSP_TYPE.map({'G':'Umumiy','C':'Maxsus'})
df.sample(5)
# Out:
#            Sno  AGE  SEX CASTE_NAME             CATEGORY_NAME  \
# 179256  179257   38  1.0         SC  GENITO URINARY SURGERIES
# 170093  170094   55  1.0         OC                CARDIOLOGY
# 189904  189905   62  1.0         BC           GENERAL SURGERY
# 218979  218980   72  0.0         OC    OPHTHALMOLOGY  SURGERY
# 168281  168282   38  1.0         BC                NEPHROLOGY
#
#                                                   SURGERY     VILLAGE  \
# 179256                                               ursl   Penukonda
# 170093              Management Of Acute MI With Angiogram  Edarapalle
# 189904      Herinoplasty with Mesh Direct Inguinal Hernia     Ponguru
# 218979  Monthly Intravitreal Anti-Vegf For Macular Deg...  Iragavaram
# 168281                   Maintenance Hemodialysis For Crf     Bathuva
#
#             PREAUTH_DATE  PREAUTH_AMT        CLAIM_DATE  CLAIM_AMOUNT  \
# 179256  25-01-2017 20:41        25000  17-03-2017 20:06         25000
# 170093  18-01-2017 15:39        30600  11-04-2017 16:06         30600
# 189904  04-02-2017 13:01        25000  03-05-2017 21:05         24100
# 218979  01-03-2017 15:28        14290  13-04-2017 21:15         14290
# 168281  16-01-2017 17:28        12500  11-05-2017 19:16         12500
#
#                                                 HOSP_NAME HOSP_TYPE  \
# 179256               SREENIVASA MULTI SPECIALITY HOSPITAL    Maxsus
# 170093  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...    Maxsus
# 189904              ABHIRAM INSTITUTE OF MEDICAL SCIENCES    Maxsus
# 218979                              Goutami Eye Institute    Maxsus
# 168281            Maharajah Institute Of Medical Sciences    Maxsus
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 179256  26-01-2017 00:00  28-01-2017 00:00              NO            NaN
# 170093  16-01-2017 00:00  19-01-2017 00:00              NO            NaN
# 189904  04-02-2017 00:00  08-02-2017 00:00              NO            NaN
# 218979  01-03-2017 00:00  02-03-2017 00:00              NO            NaN
# 168281  16-01-2017 00:00  20-02-2017 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 179256                D
# 170093                D
# 189904                D
# 218979                D
# 168281                D

# %%
#@title **To'g'ri javob**
df["HOSP_TYPE"] = df["HOSP_TYPE"].map({'G':"Umumiy", 'C':"Maxsus"})

# %% [markdown]
# #### **7-mashq**. O'zgartirish amalga oshirilgach, HOSP_TYPE ustunida qancha Umumiy va qancha Maxsus kasalxonalar borligini ham aniqlang

# %%
# Javobni shuyerga yozing
df.HOSP_TYPE.value_counts()
# Out:
# HOSP_TYPE
# Maxsus    241139
# Umumiy     94255
# Name: count, dtype: int64

# %%
#@title **To'g'ri javob**
df["HOSP_TYPE"].value_counts()

# %% [markdown]
# #### **8-mashq**. Datasetda qancha takrorlangan qatorlar borligini aniqlang

# %%
# Javobni shuyerga yozing
df.duplicated().sum()
# Out:
# 0

# %%
#@title **To'g'ri javob**
sum(df.duplicated())

# %% [markdown]
# #### **9-mashq**. Datasetda barcha takrorlangan qatorlarni o'chirib yuboring

# %%
# Javobni shuyerga yozing
df.drop_duplicates(inplace=True)

# %%
#@title **To'g'ri javob**
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### **10-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), ClAIM_AMOUNTning o'rtacha qiymatlarini toping.

# %%
df
# Out:
#            Sno  AGE  SEX CASTE_NAME             CATEGORY_NAME  \
# 0            1   56  0.0         BC                NEPHROLOGY
# 1            2   37  1.0         BC                NEPHROLOGY
# 2            3   50  1.0         BC                NEPHROLOGY
# 3            4   45  1.0         BC                NEPHROLOGY
# 4            5   54  1.0         BC                NEPHROLOGY
# ...        ...  ...  ...        ...                       ...
# 335389  335390   65  1.0         SC    OPHTHALMOLOGY  SURGERY
# 335390  335391   54  0.0         OC          MEDICAL ONCOLOGY
# 335391  335392   19  0.0         SC          MEDICAL ONCOLOGY
# 335392  335393   50  1.0         BC  GENITO URINARY SURGERIES
# 335393  335394   46  0.0         SC          MEDICAL ONCOLOGY
#
#                                                   SURGERY  \
# 0                        Maintenance Hemodialysis For Crf
# 1                        Maintenance Hemodialysis For Crf
# 2                        Maintenance Hemodialysis For Crf
# 3                        Maintenance Hemodialysis For Crf
# 4                        Maintenance Hemodialysis For Crf
# ...                                                   ...
# 335389         Vitrectomy Plus Silicon Oil Or Gas (14.75)
# 335390     Chemotherapy for Breast Cancer with Paclitaxel
# 335391       Palliative Chemotherapy for unlisted Regimen
# 335392                                               ursl
# 335393  Chemotherapy for Cervical Cancer with Weekly C...
#
#                         VILLAGE      PREAUTH_DATE  PREAUTH_AMT  \
# 0                        Lolugu  03-08-2013 20:38        12500
# 1                     Borivanka  06-08-2013 07:26        12500
# 2                   Kapasakuddi  09-08-2013 18:30        12500
# 3                   Telikipenta  24-08-2013 19:37        12500
# 4                 Thandemvalasa  28-08-2013 17:03        12500
# ...                         ...               ...          ...
# 335389             Chintalapudi  08-06-2017 06:40        23320
# 335390  Udayagiri @ Kondayapale  05-06-2017 22:35         7140
# 335391                  Vinduru  06-06-2017 06:13         5000
# 335392                Duppituru  05-06-2017 23:37        25000
# 335393             Ananthavaram  06-06-2017 23:02         2040
#
#               CLAIM_DATE  CLAIM_AMOUNT  \
# 0       22-03-2017 20:25         11000
# 1       22-03-2017 20:25         11000
# 2       22-03-2017 20:25         11500
# 3       22-03-2017 20:25         11000
# 4       22-03-2017 20:25         11000
# ...                  ...           ...
# 335389  04-08-2017 21:23         23320
# 335390  02-08-2017 19:11          7140
# 335391  04-10-2017 19:46          5000
# 335392  04-08-2017 20:59         25000
# 335393  09-08-2017 19:43          2040
#
#                                                 HOSP_NAME HOSP_TYPE  \
# 0                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 1                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 2                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 3                 Rims Govt. General Hospital, Srikakulam    Umumiy
# 4                 Rims Govt. General Hospital, Srikakulam    Umumiy
# ...                                                   ...       ...
# 335389                                Sankar Eye Hospital    Maxsus
# 335390  BASAVATARAKAM INDO AMERICAN CANCER HOSPITAL an...    Maxsus
# 335391                                    M.N.J.Hospitals    Umumiy
# 335392             GAJUWAKA HOSPITALS PVT LTD RK HOSPITAL    Maxsus
# 335393  SURYA GLOBAL MULTI SPECIALITY HOSPITALS AND CA...    Maxsus
#
#             SURGERY_DATE    DISCHARGE_DATE Mortality Y / N MORTALITY_DATE  \
# 0       06-08-2013 00:00  07-09-2013 00:00              NO            NaN
# 1       08-08-2013 00:00  09-09-2013 00:00              NO            NaN
# 2       15-08-2013 00:00  18-10-2013 00:00              NO            NaN
# 3       24-08-2013 00:00  27-09-2013 00:00              NO            NaN
# 4       31-08-2013 00:00  02-10-2013 00:00              NO            NaN
# ...                  ...               ...             ...            ...
# 335389  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335390  06-06-2017 00:00  06-06-2017 00:00              NO            NaN
# 335391  09-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335392  06-06-2017 00:00  10-06-2017 00:00              NO            NaN
# 335393  07-06-2017 00:00  07-06-2017 00:00              NO            NaN
#
#        SRC_REGISTRATION
# 0                     D
# 1                     D
# 2                     D
# 3                     D
# 4                     D
# ...                 ...
# 335389                D
# 335390                D
# 335391                D
# 335392                D
# 335393               MC
#
# [335394 rows x 18 columns]

# %%
# Javobni shuyerga yozing
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.mean()
# Out:
# HOSP_TYPE
# Maxsus    30272.214457
# Umumiy    22683.900769
# Name: CLAIM_AMOUNT, dtype: float64

# %%
#@title **To'g'ri javob**
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.mean()

# %% [markdown]
# #### **11-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), ClAIM_AMOUNTning minimum qiymatlarini toping.

# %%
# Javobni shuyerga yozing
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.min()
# Out:
# HOSP_TYPE
# Maxsus    2
# Umumiy    2
# Name: CLAIM_AMOUNT, dtype: int64

# %%
#@title **To'g'ri javob**
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.min()

# %% [markdown]
# #### **12-mashq**. Datasetdan shifoxona turiga ko'ra (umumiy va maxsus), CLAIM_AMOUNTning maksimum qiymatlarini toping.

# %%
# Javobni shuyerga yozing
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.max()
# Out:
# HOSP_TYPE
# Maxsus    520000
# Umumiy    520000
# Name: CLAIM_AMOUNT, dtype: int64

# %%
#@title **To'g'ri javob**
df.groupby('HOSP_TYPE').CLAIM_AMOUNT.max()

# %% [markdown]
# .agg() yordamida istalgan funksiyalarni chaqirishimiz mumkin, misol uchun numpy dagi mean (o'rta qiymat) funiksiyasini ham qo'shamiz. Natijalarni faqat price ustuni uchun chiqaramiz:

# %% [markdown]
# #### **13-mashq**. Datasetdan jinsiga ko'ra CLAIM_AMOUNTning min, max va o'rta qiymatlarni agg() usuli yordamida toping.

# %%
# Javobni shuyerga yozing
df.groupby('SEX').CLAIM_AMOUNT.agg([min,max,len])
# Out:
# <ipython-input-55-978dcdf026d9>:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby('SEX').CLAIM_AMOUNT.agg([min,max,len])
# <ipython-input-55-978dcdf026d9>:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby('SEX').CLAIM_AMOUNT.agg([min,max,len])
#      min     max     len
# SEX
# 0.0    2  210000  122276
# 1.0    2  205000  182976

# %%
#@title **To'g'ri javob**
df.groupby('SEX').CLAIM_AMOUNT.agg([min, max, np.mean])

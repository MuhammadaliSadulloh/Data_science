# %%
# !pip install psycopg2-binary

# %%
from pprint import pprint as print
import psycopg2 as psql

# %%
pdb = psql.connect(
    host = "localhost",
    database = "postgres",
    user = "postgres",
    password = "74123"
)
cursor1 = pdb.cursor()
cursor1.execute("SELECT version()")
print(cursor1.fetchone())
# Out:
# ('PostgreSQL 17.2 on x86_64-windows, compiled by msvc-19.42.34433, 64-bit',)

# %%
cursor1.execute('SELECT * FROM car ORDER BY id ASC;')
cursor1.fetchall()
# Out:
# [(1, 'Chevrolet', 'G-Series G30', Decimal('1995'), Decimal('56733.89')),
#  (2, 'Toyota', '4Runner', Decimal('1996'), Decimal('30391.77')),
#  (3, 'Lexus', 'RX', Decimal('2012'), Decimal('6537.82')),
#  (4, 'Dodge', 'Ram 2500', Decimal('1996'), Decimal('48262.84')),
#  (5, 'Mitsubishi', 'GTO', Decimal('1993'), Decimal('70156.81')),
#  (6, 'Lexus', 'LS', Decimal('2007'), Decimal('23342.25')),
#  (7, 'Porsche', 'Boxster', Decimal('2000'), Decimal('58733.11')),
#  (8, 'Subaru', 'Legacy', Decimal('1990'), Decimal('54683.40')),
#  (9, 'GMC', 'Savana 3500', Decimal('2002'), Decimal('90809.33')),
#  (10, 'Mitsubishi', 'Galant', Decimal('1995'), Decimal('89616.37')),
#  (11, 'GMC', 'Suburban 1500', Decimal('1996'), Decimal('18932.28')),
#  (12, 'GMC', 'Envoy XL', Decimal('2004'), Decimal('67920.47')),
#  (13, 'GMC', 'Rally Wagon 1500', Decimal('1992'), Decimal('39693.16')),
#  (14, 'Toyota', 'Matrix', Decimal('2011'), Decimal('28009.56')),
# ...

# %%
cursor1.execute("SELECT make FROM car;")
print(cursor1.fetchall())
# Out:
# [('Chevrolet',),
#  ('Toyota',),
#  ('Lexus',),
#  ('Dodge',),
#  ('Mitsubishi',),
#  ('Lexus',),
#  ('Porsche',),
#  ('Subaru',),
#  ('GMC',),
#  ('Mitsubishi',),
#  ('GMC',),
#  ('GMC',),
#  ('GMC',),
#  ('Toyota',),
#  ('Honda',),
#  ('Lexus',),
#  ('Buick',),
#  ('Mazda',),
#  ('Pontiac',),
#  ('Mercedes-Benz',),
#  ('Buick',),
#  ('Ford',),
#  ('Mitsubishi',),
#  ('Audi',),
#  ('Kia',),
#  ('Audi',),
#  ('Lincoln',),
#  ('Porsche',),
#  ('Chevrolet',),
#  ('Subaru',),
#  ('Ford',),
#  ('Dodge',),
#  ('Toyota',),
#  ('Oldsmobile',),
#  ('Ford',),
#  ('Toyota',),
#  ('Dodge',),
#  ('Kia',),
#  ('Hyundai',),
#  ('Lamborghini',),
#  ('BMW',),
#  ('Dodge',),
#  ('Chrysler',),
#  ('Mercedes-Benz',),
#  ('Mitsubishi',),
#  ('Mercedes-Benz',),
#  ('Maserati',),
#  ('Kia',),
#  ('Lexus',),
#  ('Chevrolet',),
#  ('Mitsubishi',),
#  ('Chevrolet',),
#  ('Ford',),
#  ('Ford',),
#  ('Lotus',),
#  ('Mazda',),
#  ('Chevrolet',),
#  ('Jaguar',),
#  ('Mercedes-Benz',),
#  ('Lexus',),
# ...

# %%
cursor1.execute("SELECT COUNT (*) FROM car")
cursor1.fetchone()
# Out:
# (1000,)

# %%
# cursor1.execute("PRAGMA table_info(customers);")
# cursor1.fetchall()

# %%
query = "SELECT * FROM car LIMIT 5"
df = pd.read_sql(query, pdb, index_col="id") # CustomerId ustunidan DF Indeksi sifatida foydalanamiz
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14312\1700812346.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, pdb, index_col="id") # CustomerId ustunidan DF Indeksi sifatida foydalanamiz
#           make         model    year     price
# id
# 1    Chevrolet  G-Series G30  1995.0  56733.89
# 2       Toyota       4Runner  1996.0  30391.77
# 3        Lexus            RX  2012.0   6537.82
# 4        Dodge      Ram 2500  1996.0  48262.84
# 5   Mitsubishi           GTO  1993.0  70156.81

# %%
# customers jadvalidagi barcha mijozlarni ko'rish
query = "SELECT * FROM car"
df = pd.read_sql(query, pdb, index_col="id")
df.sample(5)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14312\2553625916.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, pdb, index_col="id")
#               make     model    year     price
# id
# 86   Mercedes-Benz  SL-Class  1994.0  57799.96
# 124     Mitsubishi    Lancer  2009.0  97172.00
# 478         Nissan  Frontier  2003.0  63159.22
# 304          Dodge  Ram 3500  2010.0  59558.21
# 115        Mercury    Cougar  1987.0  76948.82

# %%
# Jadvalni chaqirishda aynan qaysi ustunlar kerakligini ham ko'rsatishimiz mumkin
query = "SELECT make, model, price FROM car LIMIT 10"
pd.read_sql(query, pdb)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14312\2167505327.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, pdb)
#          make         model     price
# 0   Chevrolet  G-Series G30  56733.89
# 1      Toyota       4Runner  30391.77
# 2       Lexus            RX   6537.82
# 3       Dodge      Ram 2500  48262.84
# 4  Mitsubishi           GTO  70156.81
# 5       Lexus            LS  23342.25
# 6     Porsche       Boxster  58733.11
# 7      Subaru        Legacy  54683.40
# 8         GMC   Savana 3500  90809.33
# 9  Mitsubishi        Galant  89616.37

# %%
# Ma'lumotlarni biror ustun bo'yicha tartiblash
query = "SELECT * FROM car ORDER BY price"
df = pd.read_sql(query, pdb, index_col="id")
df.head(10)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14312\3185777798.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, pdb, index_col="id")
#            make          model    year    price
# id
# 82         Audi             A8  2002.0  4019.14
# 57    Chevrolet         Camaro  1972.0  4053.14
# 910  Volkswagen          Jetta  1986.0  4083.32
# 324      Suzuki       Sidekick  1991.0  4133.61
# 644       Lexus             LX  2008.0  4152.77
# 540         GMC          Yukon  2004.0  4162.14
# 658      Suzuki   Grand Vitara  2000.0  4309.42
# 641    Chrysler       Concorde  2003.0  4320.24
# 790         GMC  Suburban 1500  1996.0  4466.90
# 51   Mitsubishi       Endeavor  2006.0  4640.06

# %%
# Ma'lumotlarni biror ustun bo'yicha kamayish tartyibida olish
query = "SELECT * FROM car ORDER BY price DESC"
df = pd.read_sql(query, pdb, index_col="id")
df.head(10)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14312\3211074635.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, pdb, index_col="id")
#          make       model    year     price
# id
# 821    Toyota  Highlander  2008.0  99886.78
# 517  Infiniti           G  1996.0  99840.87
# 254      Ford    F-Series  1987.0  99829.27
# 556       Kia        Soul  2010.0  99821.52
# 184     Volvo         S70  1998.0  99819.03
# 193    Toyota      Tundra  2009.0  99493.92
# 823    Toyota       Camry  2003.0  99405.12
# 480      Jeep     Patriot  2007.0  99343.48
# 213  Infiniti           M  2007.0  99239.49
# 130  Chrysler         300  2011.0  99208.15

# %%
query = "SELECT DISTINCT make FROM car"
cursor1.execute(query)
cursor1.fetchall()
# Out:
# [('Fillmore',),
#  ('McLaren',),
#  ('Ford',),
#  ('Smart',),
#  ('Maserati',),
#  ('Dodge',),
#  ('Infiniti',),
#  ('MINI',),
#  ('Bentley',),
#  ('Pontiac',),
#  ('Plymouth',),
#  ('Holden',),
#  ('Audi',),
#  ('Lexus',),
#  ('Jeep',),
#  ('Volvo',),
#  ('Acura',),
#  ('Cadillac',),
#  ('Suzuki',),
#  ('Aston Martin',),
#  ('Mitsubishi',),
#  ('Ferrari',),
#  ('Chrysler',),
#  ('Isuzu',),
#  ('GMC',),
#  ('Maybach',),
#  ('Lincoln',),
#  ('Honda',),
#  ('Ram',),
#  ('Daewoo',),
#  ('Spyker',),
#  ('Scion',),
#  ('Aptera',),
#  ('Chevrolet',),
#  ('Saturn',),
#  ('Hillman',),
#  ('Porsche',),
#  ('Alfa Romeo',),
#  ('Rolls-Royce',),
#  ('Jaguar',),
#  ('Lotus',),
#  ('Kia',),
#  ('Lamborghini',),
#  ('Mercedes-Benz',),
#  ('Oldsmobile',),
#  ('Fiat',),
#  ('Land Rover',),
#  ('Buick',),
#  ('Nissan',),
#  ('Saab',),
#  ('Hyundai',),
#  ('Geo',),
#  ('Subaru',),
#  ('Mazda',),
#  ('BMW',),
#  ('Volkswagen',),
#  ('Mercury',),
#  ('Eagle',),
#  ('Hummer',),
#  ('Toyota',)]

# %%
# natijani DF ko'rinishida olamiz
make = pd.read_sql(query, pdb)
make.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14312\3684167542.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   make = pd.read_sql(query, pdb)
#        make
# 0  Fillmore
# 1   McLaren
# 2      Ford
# 3     Smart
# 4  Maserati

# %%
obj = make['make']
print(obj)
# Out:
# 0          Fillmore
# 1           McLaren
# 2              Ford
# 3             Smart
# 4          Maserati
# 5             Dodge
# 6          Infiniti
# 7              MINI
# 8           Bentley
# 9           Pontiac
# 10         Plymouth
# 11           Holden
# 12             Audi
# 13            Lexus
# 14             Jeep
# 15            Volvo
# 16            Acura
# 17         Cadillac
# 18           Suzuki
# 19     Aston Martin
# 20       Mitsubishi
# 21          Ferrari
# 22         Chrysler
# 23            Isuzu
# 24              GMC
# 25          Maybach
# 26          Lincoln
# 27            Honda
# 28              Ram
# 29           Daewoo
# 30           Spyker
# 31            Scion
# 32           Aptera
# 33        Chevrolet
# 34           Saturn
# 35          Hillman
# 36          Porsche
# 37       Alfa Romeo
# 38      Rolls-Royce
# 39           Jaguar
# 40            Lotus
# 41              Kia
# 42      Lamborghini
# 43    Mercedes-Benz
# 44       Oldsmobile
# ...

# %%
# Braziliyalik xaridorlarni ajratib olamiz
query = "SELECT * FROM car WHERE make='Cadillac'"
df = pd.read_sql(query, pdb, index_col="id")
df.head(10)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14312\3214104620.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, pdb, index_col="id")
#          make         model    year     price
# id
# 75   Cadillac      Escalade  2007.0  40982.32
# 180  Cadillac           DTS  2008.0  23656.54
# 190  Cadillac       DeVille  1997.0  11870.43
# 236  Cadillac         STS-V  2006.0  19488.30
# 380  Cadillac  Escalade ESV  2010.0  90152.37
# 410  Cadillac        Catera  2001.0  56361.65
# 452  Cadillac         CTS-V  2012.0  15003.98
# 464  Cadillac           CTS  2004.0  79063.59
# 476  Cadillac      Eldorado  1997.0  79670.42
# 490  Cadillac  Escalade EXT  2003.0   7590.59

# %%
# Brazil va USA xaridorlarni ajratib olamiz
# Keling boshlanishiga bunday xaridorlar sonini chiqaramiz
cursor1.execute("SELECT COUNT (*) FROM car WHERE make='Cadillac' OR make='Lexus'")
print(cursor1.fetchone())
# Out:
# (51,)

# %%
# Brazil va USA xaridorlarni ajratib olamiz
query = "SELECT make, model, price FROM car WHERE make='Cadillac' OR make='Lexus'"
pd.read_sql(query, pdb)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14312\3663169156.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql(query, pdb)
#         make         model     price
# 0      Lexus            RX   6537.82
# 1      Lexus            LS  23342.25
# 2      Lexus            SC   7624.16
# 3      Lexus            IS  38720.66
# 4      Lexus            ES  81840.64
# 5   Cadillac      Escalade  40982.32
# 6      Lexus            GX  66979.20
# 7   Cadillac           DTS  23656.54
# 8      Lexus            ES  16166.85
# 9   Cadillac       DeVille  11870.43
# 10     Lexus            ES  37100.96
# 11  Cadillac         STS-V  19488.30
# 12     Lexus            LX  86301.13
# 13     Lexus            ES  29788.76
# 14     Lexus            ES  21677.30
# 15  Cadillac  Escalade ESV  90152.37
# 16     Lexus            CT  57917.39
# ...

# %%
pdb.close()

# %%
# dropna()

# %%
import pandas as pd

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df.isnull()
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0        False       False       False   False        False             False
# 1        False       False        True   False        False             False
# 2        False       False       False   False        False             False
# 3        False       False       False   False        False             False
# 4        False       False       False   False        False             False
# ...        ...         ...         ...     ...          ...               ...
# 81       False       False       False   False        False             False
# 82       False       False        True   False         True             False
# 86       False       False       False    True        False             False
# 87       False       False       False   False         True             False
# 88       False       False       False   False        False             False
#
# ...

# %%
df.isnull().sum()
# Out:
# company              0
# body-style           0
# wheel-base          15
# length              13
# engine-type         12
# num-of-cylinders     0
# horsepower          16
# average-mileage     15
# price                3
# dtype: int64

# %%
nulls=df.isnull().sum()
rows=df.shape[0]
nulls/rows*100
# Out:
# company              0.000000
# body-style           0.000000
# wheel-base          24.590164
# length              21.311475
# engine-type         19.672131
# num-of-cylinders     0.000000
# horsepower          26.229508
# average-mileage     24.590164
# price                4.918033
# dtype: float64

# %%
df2=df.dropna()
df2.shape
# Out:
# (14, 9)

# %%
df.dropna(axis=1)
# Out:
#            company   body-style num-of-cylinders
# index
# 0      alfa-romero  convertible             four
# 1      alfa-romero  convertible             four
# 2      alfa-romero    hatchback              six
# 3             audi        sedan             four
# 4             audi        sedan             five
# ...            ...          ...              ...
# 81      volkswagen        sedan             four
# 82      volkswagen        sedan             four
# 86      volkswagen        sedan             four
# 87           volvo        sedan             four
# 88           volvo        wagon             four
#
# [61 rows x 3 columns]

# %%
df.dropna(axis=1, thresh=48)#48tadan ko'p qiymatga ega bo'lmagan ustunlarni o'chirib tashlash
# Out:
#            company   body-style  length engine-type num-of-cylinders    price
# index
# 0      alfa-romero  convertible   168.8        dohc             four  13495.0
# 1      alfa-romero  convertible   168.8        dohc             four  16500.0
# 2      alfa-romero    hatchback   171.2        ohcv              six  16500.0
# 3             audi        sedan   176.6         ohc             four  13950.0
# 4             audi        sedan   176.6         ohc             five  17450.0
# ...            ...          ...     ...         ...              ...      ...
# 81      volkswagen        sedan   171.7         ohc             four   7975.0
# 82      volkswagen        sedan   171.7         NaN             four   7995.0
# 86      volkswagen        sedan     NaN         ohc             four   9995.0
# 87           volvo        sedan   188.8         NaN             four  12940.0
# 88           volvo        wagon   188.8         ohc             four  13415.0
#
# [61 rows x 6 columns]

# %%
df.dropna(subset=['length','body-style'])
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 0        alfa-romero  convertible        88.6   168.8        dohc
# 1        alfa-romero  convertible         NaN   168.8        dohc
# 2        alfa-romero    hatchback        94.5   171.2        ohcv
# 3               audi        sedan        99.8   176.6         ohc
# 4               audi        sedan        99.4   176.6         ohc
# 5               audi        sedan        99.8   177.3         ohc
# 6               audi        wagon       105.8   192.7         ohc
# 10               bmw        sedan         NaN   176.8         ohc
# 11               bmw        sedan       101.2   176.8         ohc
# 13               bmw        sedan       103.5   189.0         ohc
# 15               bmw        sedan       110.0   197.0         ohc
# 16         chevrolet    hatchback        88.4   141.1           l
# 17         chevrolet    hatchback        94.5   155.9         ohc
# ...

# %%
df.dropna(subset='price',inplace=True)

# %%
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
# fillna()

# %%
import numpy as np

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df.fillna(0)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         0.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         0.0   171.7           0
# 86      volkswagen        sedan        97.3     0.0         ohc
# 87           volvo        sedan       104.3   188.8           0
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         0.0             21.0  13495.0
# ...

# %%
df['wheel-base'].mean()
# Out:
# 99.2195652173913

# %%
df['horsepower'].mean()
# Out:
# 108.26666666666667

# %%
df.fillna({'wheel-base':df['wheel-base'].mean(),'horsepower':df['horsepower'].mean()})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible   88.600000   168.8        dohc
# 1      alfa-romero  convertible   99.219565   168.8        dohc
# 2      alfa-romero    hatchback   94.500000   171.2        ohcv
# 3             audi        sedan   99.800000   176.6         ohc
# 4             audi        sedan   99.400000   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan   97.300000   171.7         ohc
# 82      volkswagen        sedan   99.219565   171.7         NaN
# 86      volkswagen        sedan   97.300000     NaN         ohc
# 87           volvo        sedan  104.300000   188.8         NaN
# 88           volvo        wagon  104.300000   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four  108.266667             21.0  13495.0
# ...

# %%
df[df.company=='audi']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 3        audi      sedan        99.8   176.6         ohc             four
# 4        audi      sedan        99.4   176.6         ohc             five
# 5        audi      sedan        99.8   177.3         ohc             five
# 6        audi      wagon       105.8   192.7         ohc             five
#
#        horsepower  average-mileage    price
# index
# 3           102.0             24.0  13950.0
# 4             NaN              NaN  17450.0
# 5           110.0             19.0  15250.0
# 6           110.0             19.0  18920.0

# %%
df[df.company=='audi'].fillna(method='ffill')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13496\3827244152.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[df.company=='audi'].fillna(method='ffill')
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 3        audi      sedan        99.8   176.6         ohc             four
# 4        audi      sedan        99.4   176.6         ohc             five
# 5        audi      sedan        99.8   177.3         ohc             five
# 6        audi      wagon       105.8   192.7         ohc             five
#
#        horsepower  average-mileage    price
# index
# 3           102.0             24.0  13950.0
# 4           102.0             24.0  17450.0
# 5           110.0             19.0  15250.0
# 6           110.0             19.0  18920.0

# %%
df[df.company=='toyota']
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback         NaN   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         NaN             four
# 68     toyota  hatchback         NaN   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7     NaN         NaN             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67            NaN             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71            NaN             27.0   8778.0
# 79          156.0              NaN  15750.0

# %%
df[df.company=='toyota'].fillna(method='bfill')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13496\810867158.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[df.company=='toyota'].fillna(method='bfill')
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# ...

# %%
df[df.company=='toyota']=df[df.company=='toyota'].fillna(method='bfill')
df[df.company=='toyota']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13496\2023266913.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[df.company=='toyota']=df[df.company=='toyota'].fillna(method='bfill')
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# ...

# %%
dfhatch=df[df['body-style']=='hatchback']
dfhatch
# Out:
#            company body-style  wheel-base  length engine-type  \
# index
# 2      alfa-romero  hatchback        94.5   171.2        ohcv
# 16       chevrolet  hatchback        88.4   141.1           l
# 17       chevrolet  hatchback        94.5   155.9         ohc
# 19           dodge  hatchback        93.7   157.3         ohc
# 20           dodge  hatchback        93.7     NaN         ohc
# 36           mazda  hatchback        93.1   159.1         NaN
# 37           mazda  hatchback        93.1   159.1         ohc
# 38           mazda  hatchback        93.1   159.1         ohc
# 39           mazda  hatchback         NaN     NaN         NaN
# 49      mitsubishi  hatchback         NaN   157.3         ohc
# 50      mitsubishi  hatchback        93.7     NaN         NaN
# 63         porsche  hatchback        98.4   175.7       dohcv
# 66          toyota  hatchback        95.7   158.7         ohc
# 67          toyota  hatchback        95.7   158.7         ohc
# ...

# %%
dfhatch.fillna(dfhatch.select_dtypes(include=['number']).mean())
# Out:
#            company body-style  wheel-base   length engine-type  \
# index
# 2      alfa-romero  hatchback        94.5  171.200        ohcv
# 16       chevrolet  hatchback        88.4  141.100           l
# 17       chevrolet  hatchback        94.5  155.900         ohc
# 19           dodge  hatchback        93.7  157.300         ohc
# 20           dodge  hatchback        93.7  159.325         ohc
# 36           mazda  hatchback        93.1  159.100         NaN
# 37           mazda  hatchback        93.1  159.100         ohc
# 38           mazda  hatchback        93.1  159.100         ohc
# 39           mazda  hatchback        94.1  159.325         NaN
# 49      mitsubishi  hatchback        94.1  157.300         ohc
# 50      mitsubishi  hatchback        93.7  159.325         NaN
# 63         porsche  hatchback        98.4  175.700       dohcv
# 66          toyota  hatchback        95.7  158.700         ohc
# 67          toyota  hatchback        95.7  158.700         ohc
# ...

# %%
df.fillna({'horsepower':np.mean(df['horsepower']), "wheel-base":np.mean(df['wheel-base'])})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible   88.600000   168.8        dohc
# 1      alfa-romero  convertible   99.072917   168.8        dohc
# 2      alfa-romero    hatchback   94.500000   171.2        ohcv
# 3             audi        sedan   99.800000   176.6         ohc
# 4             audi        sedan   99.400000   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan   97.300000   171.7         ohc
# 82      volkswagen        sedan   99.072917   171.7         NaN
# 86      volkswagen        sedan   97.300000     NaN         ohc
# 87           volvo        sedan  104.300000   188.8         NaN
# 88           volvo        wagon  104.300000   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four  108.297872             21.0  13495.0
# ...

# %%
# drop_duplicates(), map(), replace(), rename()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv')
df.head()
# Out:
#    rank  country     density   densityMi    pop2021   area
# 0     1    Macau  21946.4667  56841.3487    658.394     30
# 1     2   Monaco  19755.5000  51166.7450     39.511      2
# 2    28  Burundi    440.3044   1140.3884  12255.433  27834
# 3     1    Macau  21946.4667  56841.3487    658.394     30
# 4     2   Monaco  19755.5000  51166.7450     39.511      2

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 242    False
# 243    False
# 244    False
# 245    False
# 246    False
# Length: 247, dtype: bool

# %%
df.shape
# Out:
# (247, 6)

# %%
df.drop_duplicates()
# Out:
#      rank           country     density   densityMi    pop2021     area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 5       3         Singapore   8305.1915  21510.4461   5896.686      710
# 6       4         Hong Kong   6841.3134  17719.0017   7552.810     1104
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [232 rows x 6 columns]

# %%
df.drop_duplicates(['country'])
# Out:
#      rank           country     density   densityMi    pop2021     area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 5       3         Singapore   8305.1915  21510.4461   5896.686      710
# 6       4         Hong Kong   6841.3134  17719.0017   7552.810     1104
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [232 rows x 6 columns]

# %%
df.drop_duplicates(['country','rank'])
# Out:
#      rank           country     density   densityMi    pop2021     area
# 0       1             Macau  21946.4667  56841.3487    658.394       30
# 1       2            Monaco  19755.5000  51166.7450     39.511        2
# 2      28           Burundi    440.3044   1140.3884  12255.433    27834
# 5       3         Singapore   8305.1915  21510.4461   5896.686      710
# 6       4         Hong Kong   6841.3134  17719.0017   7552.810     1104
# ..    ...               ...         ...         ...        ...      ...
# 242   228           Namibia      3.1338      8.1166   2587.344   825615
# 243   229    Western Sahara      2.3003      5.9577    611.875   266000
# 244   230          Mongolia      2.1286      5.5129   3329.289  1564110
# 245   231  Falkland Islands      0.2902      0.7517      3.533    12173
# 246   232         Greenland      0.0263      0.0680     56.877  2166086
#
# [232 rows x 6 columns]

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data_nan.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
arr={'four':4,'six':6,'five':5,'three':3,'twelve':12,'two':2,'eight':8}

# %%
df['cylinders']=df['num-of-cylinders'].map(arr)

# %%
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders
# index
# 0                 four         NaN             21.0  13495.0          4
# 1                 four       111.0             21.0  16500.0          4
# 2                  six       154.0              NaN  16500.0          6
# 3                 four       102.0             24.0  13950.0          4
# 4                 five         NaN              NaN  17450.0          5

# %%
kurs=13000
df['price_uz']=df.price.map(lambda x:x*kurs)

# %%
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                 four         NaN             21.0  13495.0          4
# ...

# %%
df['num-of-cylinders'].replace(arr)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13496\3819276597.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['num-of-cylinders'].replace(arr)
# index
# 0     4
# 1     4
# 2     6
# 3     4
# 4     5
#      ..
# 81    4
# 82    4
# 86    4
# 87    4
# 88    4
# Name: num-of-cylinders, Length: 61, dtype: int64

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv', index_col='country')

# %%
df2.head()
# Out:
#          rank     density   densityMi    pop2021   area
# country
# Macau       1  21946.4667  56841.3487    658.394     30
# Monaco      2  19755.5000  51166.7450     39.511      2
# Burundi    28    440.3044   1140.3884  12255.433  27834
# Macau       1  21946.4667  56841.3487    658.394     30
# Monaco      2  19755.5000  51166.7450     39.511      2

# %%
df2.rename(index=str.upper,columns=str.upper)
# Out:
#                   RANK     DENSITY   DENSITYMI    POP2021     AREA
# country
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# BURUNDI             28    440.3044   1140.3884  12255.433    27834
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# ...                ...         ...         ...        ...      ...
# NAMIBIA            228      3.1338      8.1166   2587.344   825615
# WESTERN SAHARA     229      2.3003      5.9577    611.875   266000
# MONGOLIA           230      2.1286      5.5129   3329.289  1564110
# FALKLAND ISLANDS   231      0.2902      0.7517      3.533    12173
# GREENLAND          232      0.0263      0.0680     56.877  2166086
#
# [247 rows x 5 columns]

# %%
df2.rename(index={'Macau':'Makao'},columns={'pop2021':'population'})
# Out:
#                   rank     density   densityMi  population     area
# country
# Makao                1  21946.4667  56841.3487     658.394       30
# Monaco               2  19755.5000  51166.7450      39.511        2
# Burundi             28    440.3044   1140.3884   12255.433    27834
# Makao                1  21946.4667  56841.3487     658.394       30
# Monaco               2  19755.5000  51166.7450      39.511        2
# ...                ...         ...         ...         ...      ...
# Namibia            228      3.1338      8.1166    2587.344   825615
# Western Sahara     229      2.3003      5.9577     611.875   266000
# Mongolia           230      2.1286      5.5129    3329.289  1564110
# Falkland Islands   231      0.2902      0.7517       3.533    12173
# Greenland          232      0.0263      0.0680      56.877  2166086
#
# [247 rows x 5 columns]

# %%
# Guruhlash. cut() va qcut()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population_duplicates.csv', usecols=['country','pop2021','area'], index_col='country')
df.head()
# Out:
#            pop2021   area
# country
# Macau      658.394     30
# Monaco      39.511      2
# Burundi  12255.433  27834
# Macau      658.394     30
# Monaco      39.511      2

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#              pop2021   area
# country
# Macau        658.394     30
# Monaco        39.511      2
# Burundi    12255.433  27834
# Singapore   5896.686    710
# Hong Kong   7552.810   1104

# %%
df.sort_index(inplace=True)

# %%
df.loc['China']
# Out:
# pop2021    1444216.107
# area       9706961.000
# Name: China, dtype: float64

# %%
df.loc['Uzbekistan']
# Out:
# pop2021     33935.763
# area       447400.000
# Name: Uzbekistan, dtype: float64

# %%
bins = [0, 1000, 10000, 30000, 50000, 100000, 300000, 1500000]

# %%
population=df.pop2021

# %%
pd.cut(population,bins)
# Out:
# country
# Afghanistan          (30000, 50000]
# Albania               (1000, 10000]
# Algeria              (30000, 50000]
# American Samoa            (0, 1000]
# Andorra                   (0, 1000]
#                           ...
# Wallis and Futuna         (0, 1000]
# Western Sahara            (0, 1000]
# Yemen                (30000, 50000]
# Zambia               (10000, 30000]
# Zimbabwe             (10000, 30000]
# Name: pop2021, Length: 232, dtype: category
# Categories (7, interval[int64, right]): [(0, 1000] < (1000, 10000] < (10000, 30000] < (30000, 50000] < (50000, 100000] < (100000, 300000] < (300000, 1500000]]

# %%
pd.cut(population,bins).value_counts()
# Out:
# pop2021
# (0, 1000]            72
# (1000, 10000]        68
# (10000, 30000]       44
# (30000, 50000]       19
# (50000, 100000]      15
# (100000, 300000]     11
# (300000, 1500000]     3
# Name: count, dtype: int64

# %%
df['popbins']=pd.cut(population,bins)

# %%
df.head()
# Out:
#                   pop2021     area         popbins
# country
# Afghanistan     39835.428   652230  (30000, 50000]
# Albania          2872.933    28748   (1000, 10000]
# Algeria         44616.624  2381741  (30000, 50000]
# American Samoa     55.100      199       (0, 1000]
# Andorra            77.355      468       (0, 1000]

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
df.price.describe()
# Out:
# count       58.000000
# mean     15387.000000
# std      11320.259841
# min       5151.000000
# 25%       6808.500000
# 50%      11095.000000
# 75%      18120.500000
# max      45400.000000
# Name: price, dtype: float64

# %%
bins=[0,10000,20000,50000]

# %%
range=pd.cut(df.price,bins)

# %%
range.value_counts()
# Out:
# price
# (0, 10000]        28
# (10000, 20000]    17
# (20000, 50000]    13
# Name: count, dtype: int64

# %%
groups = ["arzon", "o'rta", "qimmat"]
range = pd.cut(df.price, bins, labels=groups)
range.value_counts()
# Out:
# price
# arzon     28
# o'rta     17
# qimmat    13
# Name: count, dtype: int64

# %%
range = pd.cut(df.price, 3)
range.value_counts()
# Out:
# price
# (5110.751, 18567.333]     44
# (31983.667, 45400.0]       9
# (18567.333, 31983.667]     5
# Name: count, dtype: int64

# %%
range = pd.cut(df.price, 4)
range.value_counts()
# Out:
# price
# (5110.751, 15213.25]    36
# (15213.25, 25275.5]     10
# (35337.75, 45400.0]      7
# (25275.5, 35337.75]      5
# Name: count, dtype: int64

# %%
range = pd.qcut(df.price, 3)
range.value_counts()
# Out:
# price
# (16430.0, 45400.0]    20
# (5150.999, 7295.0]    19
# (7295.0, 16430.0]     19
# Name: count, dtype: int64

# %%
range = pd.qcut(df.horsepower, 3)
range.value_counts()
# Out:
# horsepower
# (47.999, 70.0]    24
# (111.0, 288.0]    20
# (70.0, 111.0]     17
# Name: count, dtype: int64

# %%
# groupby()

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/automobile_data.csv", index_col=0)
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
df.select_dtypes(include=['number']).groupby('wheel-base').mean()
# Out:
#                 length  horsepower  average-mileage         price
# wheel-base
# 88.4        141.100000   48.000000        47.000000   5151.000000
# 88.6        168.800000  111.000000        21.000000  14997.500000
# 89.5        168.900000  207.000000        17.000000  35528.000000
# 93.1        159.100000   68.000000        30.666667   6028.333333
# 93.7        157.300000   68.000000        32.500000   6046.000000
# 94.3        170.700000   78.000000        24.000000   6785.000000
# 94.5        162.644444   77.333333        34.333333   8188.000000
# 95.3        169.000000  101.000000        17.000000  11845.000000
# 95.7        164.200000   62.000000        30.333333   6961.333333
# 96.3        172.400000   88.000000        25.000000   7589.000000
# 96.5        167.200000   92.333333        26.333333  10195.000000
# 97.3        171.700000   72.250000        31.750000   8435.000000
# 98.4        175.700000  288.000000        17.000000           NaN
# ...

# %%
df.groupby('company').price.max()
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %%
df.groupby(['company','body-style']).max()
# Out:
#                            wheel-base  length engine-type num-of-cylinders  \
# company       body-style
# alfa-romero   convertible        88.6   168.8        dohc             four
#               hatchback          94.5   171.2        ohcv              six
# audi          sedan              99.8   177.3         ohc             four
#               wagon             105.8   192.7         ohc             five
# bmw           sedan             110.0   197.0         ohc              six
# chevrolet     hatchback          94.5   155.9         ohc            three
#               sedan              94.5   158.8         ohc             four
# dodge         hatchback          93.7   157.3         ohc             four
# honda         sedan              96.5   175.4         ohc             four
#               wagon              96.5   157.1         ohc             four
# isuzu         sedan              94.5   170.7         ohc             four
# ...

# %%
df.groupby('company').agg([min,max,len])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13496\824655354.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby('company').agg([min,max,len])
# C:\Users\user\AppData\Local\Temp\ipykernel_13496\824655354.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby('company').agg([min,max,len])
# C:\Users\user\AppData\Local\Temp\ipykernel_13496\824655354.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
# ...

# %%
df.groupby('body-style').price.agg([len, min, max, np.mean])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_13496\614320205.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby('body-style').price.agg([len, min, max, np.mean])
# C:\Users\user\AppData\Local\Temp\ipykernel_13496\614320205.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby('body-style').price.agg([len, min, max, np.mean])
# ...

# %%
# FOYDALI FUNKSIYALAR

# %%
df = pd.read_csv("https://github.com/anvarnarz/praktikum_datasets/raw/main/MOCK_USER_DATA.csv", index_col=0)
df.head()
# Out:
#    first_name   last_name                           email       gender   age
# id
# 1     Dorothy     Verryan               dverryan0@who.int   Non-binary     1
# 2     Pietrek     Scanlin          pscanlin1@yolasite.com         Male    91
# 3      Lilith    Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 4        Knox  Cunningham    kcunningham3@yellowpages.com  Genderfluid     6
# 5    Mohammed  Habbershon    mhabbershon4@sourceforge.net       Female    48

# %%
df.describe()
# Out:
#                age
# count   100.000000
# mean    145.660000
# std     565.631411
# min     -85.000000
# 25%      22.750000
# 50%      53.500000
# 75%      84.250000
# max    4444.000000

# %%
df[df.age>123]
# Out:
#     first_name  last_name                           email       gender   age
# id
# 3       Lilith   Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 39      Godard      Miere               gmiere12@1688.com   Polygender  3434
# 47       Cleve  Sparshatt      csparshatt1a@economist.com  Genderfluid   333
# 49       Trace   Stockney          tstockney1c@flavors.me       Female   344
# 65      Eloise    Snoddon    esnoddon1s@elegantthemes.com  Genderfluid   332
# 80       Gabie     Rothon              grothon27@ehow.com  Genderqueer  4444
# 100      Mable    Toffano          mtoffano2r@myspace.com     Bigender   233

# %%
idx = df[df.age>123].index
idx
# Out:
# Index([3, 39, 47, 49, 65, 80, 100], dtype='int64', name='id')

# %%
df[df.age<0]
# Out:
#    first_name  last_name                           email       gender  age
# id
# 11     Elijah      Heine                eheinea@imdb.com     Bigender  -85
# 19      Luisa  Bradborne            lbradbornei@fema.gov       Female  -75
# 21      Levin     Worner                lwornerk@ihg.com  Genderqueer  -43
# 33   Ebenezer    Greeves           egreevesw@myspace.com         Male  -26
# 38       Hana   Langwade  hlangwade11@washingtonpost.com  Genderqueer  -42
# 90  Zachariah      Meins            zmeins2h@weather.com         Male  -69

# %%
df[(df.age<0)| (df.age>123)]
# Out:
#     first_name  last_name                           email       gender   age
# id
# 3       Lilith   Sarjeant  lsarjeant2@creativecommons.org  Genderfluid  1233
# 11      Elijah      Heine                eheinea@imdb.com     Bigender   -85
# 19       Luisa  Bradborne            lbradbornei@fema.gov       Female   -75
# 21       Levin     Worner                lwornerk@ihg.com  Genderqueer   -43
# 33    Ebenezer    Greeves           egreevesw@myspace.com         Male   -26
# 38        Hana   Langwade  hlangwade11@washingtonpost.com  Genderqueer   -42
# 39      Godard      Miere               gmiere12@1688.com   Polygender  3434
# 47       Cleve  Sparshatt      csparshatt1a@economist.com  Genderfluid   333
# 49       Trace   Stockney          tstockney1c@flavors.me       Female   344
# 65      Eloise    Snoddon    esnoddon1s@elegantthemes.com  Genderfluid   332
# 80       Gabie     Rothon              grothon27@ehow.com  Genderqueer  4444
# ...

# %%
df['age']=df.age. apply(np.abs)

# %%
df.sample(10)
# Out:
#    first_name    last_name                         email       gender  age
# id
# 57   Salvador      Dusting         sdusting1k@tripod.com   Non-binary   96
# 58     Brynna       Worsom              bworsom1l@wp.com         Male   66
# 90  Zachariah        Meins          zmeins2h@weather.com         Male   69
# 51  Gwendolin      Kennion  gkennion1e@independent.co.uk     Bigender   83
# 66     Alejoa   Abrahamoff         aabrahamoff1t@com.com   Polygender   28
# 24       Mart       Brosel              mbroseln@cdc.gov  Genderfluid   22
# 42     Dermot       Dragge        ddragge15@google.co.jp  Genderfluid   37
# 17      Byram  Martynikhin     bmartynikhing@jiathis.com         Male   40
# 15       Suzy      Bortoli           sbortolie@opera.com      Agender  100
# 77     Rudolf       Kalewe           rkalewe24@fotki.com         Male   12

# %%
idx=df[df.age>123].index

# %%
df.drop(index=idx,inplace=True)

# %%
df.describe()
# Out:
#               age
# count   93.000000
# mean    52.612903
# std     29.978265
# min      1.000000
# 25%     29.000000
# 50%     52.000000
# 75%     77.000000
# max    100.000000

# %%
df.gender.value_counts()
# Out:
# gender
# Male           21
# Bigender       12
# Genderfluid    11
# Female         11
# Non-binary     10
# Genderqueer    10
# Agender         9
# Polygender      9
# Name: count, dtype: int64

# %%
df[df.gender.isin(['Male','Female'])].sample(10)
# Out:
#    first_name    last_name                         email  gender  age
# id
# 43       Bili    Swetenham        bswetenham16@europa.eu    Male   23
# 62     Kennan        Visco          kvisco1p@jiathis.com  Female   94
# 87      Peder       Murrie       pmurrie2e@bloglovin.com    Male   69
# 12  Raffaello    Firminger     rfirmingerb@bloomberg.com  Female   74
# 91      Judas       Maffin         jmaffin2i@dropbox.com    Male    3
# 17      Byram  Martynikhin     bmartynikhing@jiathis.com    Male   40
# 61       Page      Merrell     pmerrell1o@slideshare.net    Male    1
# 63   Adrianne      Gommowe  agommowe1q@deliciousdays.com    Male  100
# 34     Brooks         Vose             bvosex@amazon.com  Female   34
# 76      Misty        Blanc         mblanc23@amazon.co.jp    Male   74

# %%
len(df)
# Out:
# 93

# %%
randlist = np.random.permutation(93)
randlist
# Out:
# array([53, 40, 48, 21, 66, 24, 15, 17, 92, 39, 33, 78, 41,  9, 38, 83, 43,
#        90, 27, 56, 71, 25, 89, 23, 74, 86, 51, 85, 63, 77, 44,  2, 34, 65,
#        11, 37, 26, 20, 28, 35, 70, 80, 16, 19, 42, 13, 82, 36,  1, 87, 64,
#        18, 69, 73, 84, 57, 60, 91, 54, 76,  3, 72, 30, 61, 58, 12, 59,  4,
#        67, 55, 46, 29, 22, 88, 62, 79, 10, 68, 14, 45, 47, 75, 81, 49, 32,
#         8,  0, 52, 31,  7,  5, 50,  6])

# %%
df.take(randlist)
# Out:
#    first_name  last_name                     email       gender  age
# id
# 58     Brynna     Worsom          bworsom1l@wp.com         Male   66
# 43       Bili  Swetenham    bswetenham16@europa.eu         Male   23
# 53    Demeter    Widdall     dwiddall1g@flavors.me     Bigender   90
# 23    Linnell      Picot  lpicotm@biblegateway.com  Genderfluid   79
# 72   Eleanora    Kamenar   ekamenar1z@examiner.com         Male   47
# ..        ...        ...                       ...          ...  ...
# 33   Ebenezer    Greeves     egreevesw@myspace.com         Male   26
# 9         Der     Neames  dneames8@ycombinator.com     Bigender   77
# 7       Wendy    Popland          wpopland6@cbc.ca  Genderfluid   67
# 55      Hiram   Bringloe        hbringloe1i@pen.io   Polygender   50
# 8         Nye  Anthiftle  nanthiftle7@examiner.com      Agender   99
#
# [93 rows x 5 columns]
